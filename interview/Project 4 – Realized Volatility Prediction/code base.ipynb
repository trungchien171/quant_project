# %% [markdown]
# - From Kaggle - Optiver
#
#
# This data set contains stock market data relevant to the practical execution of trades in the financial markets.
#
# In particular, it includes order book snapshots and executed trades.
#
# With one second resolution, it provides a uniquely fine grained look at the micro-structure of modern financial markets.

# %%
import os 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

# %% [markdown]
# - Order Book File
#
# From Kaggle the order book file: Provides order book data on the most competitive buy and sell orders entered into the market.The top two levels of the book are shared. The first level of the book will be more competitive in price terms, it will then receive execution priority over the second level.
#
# In the following we use stock_id==0 as example, we can see that
#
#  - bid-price from Buyer: the "maximun" dollar that "buyer" can accept
# $$ bid price1 > bid price2 $$
#
#  - ask-price from Seller: the "minimum" dollar that "seller" can accept
# $$ ask price1 < ask price2 $$
#
# bid/ask_size the number of volumne correspond to the price.

# %%
example_book_df = pd.read_parquet(r'D:\github\quant_project\optiver_dataset\book_train.parquet\stock_id=0\c439ef22282f412ba39e9137a3fdabac.parquet')
example_book_df
# Out:
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0             5                  0    1.001422    1.002301    1.001370
# 1             5                  1    1.001422    1.002301    1.001370
# 2             5                  5    1.001422    1.002301    1.001370
# 3             5                  6    1.001422    1.002301    1.001370
# 4             5                  7    1.001422    1.002301    1.001370
# ...         ...                ...         ...         ...         ...
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2
# 0         1.002353          3        226          2        100
# 1         1.002353          3        100          2        100
# 2         1.002405          3        100          2        100
# 3         1.002405          3        126          2        100
# 4         1.002405          3        126          2        100
# ...            ...        ...        ...        ...        ...
# 917548    0.998946         90         90         48         28
# 917549    0.998946         91         90        200         28
# 917550    0.998946         91         90        100         28
# 917551    0.998946         92         90        100         28
# 917552    0.998946         92         90         26         28
#
# [917553 rows x 10 columns]

# %%
example_book_df[:10].to_excel(r'trade_book_sample_data.xlsx')

# %% [markdown]
# - Trade book File

# %% [markdown]
# In the below trade_book_df, we can point out that in time_id 5 21 seconds in buckets, we have traded share volumne size 326 for stock_id==0, and how many transaction was happend for order_count.
#
# order_count - The number of unique trade orders taking place.
#
# price - The average price of executed transactions happening in one second. Prices have been normalized and the average has been weighted by the number of shares traded in each transaction.

# %%
example_trade_book_df = pd.read_parquet(r'D:\github\quant_project\optiver_dataset\trade_train.parquet\stock_id=1\170b39f1f7144bb3b4554aabc336106e.parquet')
example_trade_book_df
# Out:
#         time_id  seconds_in_bucket     price  size  order_count
# 0             5                 28  1.002080   553           11
# 1             5                 39  1.002460     8            3
# 2             5                 42  1.002308   147            4
# 3             5                 44  1.002788     1            1
# 4             5                 51  1.002657   100            2
# ...         ...                ...       ...   ...          ...
# 296205    32767                579  0.999010    81            3
# 296206    32767                587  0.999109    50            1
# 296207    32767                588  0.999010   126            2
# 296208    32767                592  0.999109     1            1
# 296209    32767                593  0.998911     1            1
#
# [296210 rows x 5 columns]

# %% [markdown]
# # Order book statistics and visulization
#
# - Bid/Ask Spread
#
#     - (best offer price/ best asking price) - 1
#
# if bid/ask spread is higher, that means the liquidity for the single asset is not great. The lower the bid/ask spread the better the marekt liquidity for the specific asset.
#
# - Weighted Averaged Price (WAP)
#
# The order book is also one of the primary source for stock valuation. A fair book-based valuation must take two factors into account: the level and the size of orders.
#
#
# $$ WAP = \frac{BidPrice_{1} * AskSize_{1} + AskPrice_{1} * BidSize_{1}}{BidSize_{1}+AskSize_{1} } $$
#
# As you can see, if two books have both bid and ask offers on the same price level respectively, The one with more offers in place will generate a lower stock valuation, as there are more intended seller in the book, and more seller implies a fact of more supply on the market resulting in a lower stock valuation.
#
# - bid price = 1, ask price =2
#
#     - More Buyer, more bid szie, therefore higher WAP
#
# $$ WAP_{1} = \frac{1 * 1 + 2 * 2}{3}  = \frac{5}{3}$$
#
# - bid price = 1, ask price =2
#
#     - More Seller, more ask szie,  therefore lower WAP
#
#
# $$ WAP_{2} = \frac{1 * 2 + 2 * 1}{3}  = \frac{4}{3}$$
#
#
# Note that in most of cases, during the continuous trading hours, an order book should not have the scenario when bid order is higher than the offer, or ask, order. In another word, most likely, the bid and ask should never be in cross.
#
# - Log Return
#
# $$ r_{t1,t2} = log(\frac{S_{t2}}{S_{t1}}) $$

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots(figsize=(8,6))
ax.set_title('Log Retrurn is not bounded and can go below -100%')
ax.axhline(0,color='red',linestyle='--')
ax.axvline(0,color='red',linestyle='--')
ax.plot(x,np.log(x),color='blue')
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11148\3517178107.py:6: RuntimeWarning: divide by zero encountered in log
#   ax.plot(x,np.log(x),color='blue')

# %% [markdown]
# - Realized Volatility
#
# We want to keep definitions as simple and clear as possible, so that Kagglers without financial knowledge will not be penalized.
#
# So we are not annualizing the volatility and we are assuming that log returns have 0 mean.
#
# $$ \sigma = \sqrt{ \sum_{t}r^{2}_{t-1,t}}$$
#
# Usually the sigma a.k.a volatility, is the sum of the square root of the difference between return and mean return
#
# $$ \sigma = \sqrt{ \sum_{t}(r_{t-1,t}-r_{mean})^{2}}$$

# %%
def log_return(list_stock_prices):
    return np.log(list_stock_prices).diff() 


example_book_df.loc[:,('bid/ask spread')] = (example_book_df['ask_price1']/example_book_df['bid_price1'])-1 # Constrcut Bid/Ask Spread.
example_book_df.loc[:,('Total bid/ask1 Size')] = example_book_df['ask_size1'] + example_book_df['bid_size1'] 
example_book_df.loc[:,('wap')] = (example_book_df['bid_price1']*example_book_df['ask_size1'] + example_book_df['ask_price1']*example_book_df['bid_size1']) / (example_book_df['ask_size1'] + example_book_df['bid_size1'])
example_book_df
# Out:
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 0             5                  0    1.001422    1.002301    1.001370
# 1             5                  1    1.001422    1.002301    1.001370
# 2             5                  5    1.001422    1.002301    1.001370
# 3             5                  6    1.001422    1.002301    1.001370
# 4             5                  7    1.001422    1.002301    1.001370
# ...         ...                ...         ...         ...         ...
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2  \
# 0         1.002353          3        226          2        100
# 1         1.002353          3        100          2        100
# 2         1.002405          3        100          2        100
# 3         1.002405          3        126          2        100
# 4         1.002405          3        126          2        100
# ...            ...        ...        ...        ...        ...
# 917548    0.998946         90         90         48         28
# 917549    0.998946         91         90        200         28
# 917550    0.998946         91         90        100         28
# 917551    0.998946         92         90        100         28
# 917552    0.998946         92         90         26         28
#
#         bid/ask spread  Total bid/ask1 Size       wap
# 0             0.000878                  229  1.001434
# 1             0.000878                  103  1.001448
# 2             0.000878                  103  1.001448
# 3             0.000878                  129  1.001443
# 4             0.000878                  129  1.001443
# ...                ...                  ...       ...
# 917548        0.000480                  180  0.998515
# 917549        0.000480                  181  0.998516
# 917550        0.000480                  181  0.998516
# 917551        0.000480                  182  0.998517
# 917552        0.000480                  182  0.998517
#
# [917553 rows x 13 columns]

# %%
example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
example_book_df = example_book_df[~example_book_df['log_return'].isnull()] # drop the first null return value
example_book_df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1458396147.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#         time_id  seconds_in_bucket  bid_price1  ask_price1  bid_price2  \
# 1             5                  1    1.001422    1.002301    1.001370
# 2             5                  5    1.001422    1.002301    1.001370
# 3             5                  6    1.001422    1.002301    1.001370
# 4             5                  7    1.001422    1.002301    1.001370
# 5             5                 11    1.001422    1.002301    1.001370
# ...         ...                ...         ...         ...         ...
# 917548    32767                568    0.998275    0.998754    0.997796
# 917549    32767                569    0.998275    0.998754    0.997892
# 917550    32767                571    0.998275    0.998754    0.997892
# 917551    32767                572    0.998275    0.998754    0.997892
# 917552    32767                582    0.998275    0.998754    0.998179
#
#         ask_price2  bid_size1  ask_size1  bid_size2  ask_size2  \
# 1         1.002353          3        100          2        100
# 2         1.002405          3        100          2        100
# 3         1.002405          3        126          2        100
# 4         1.002405          3        126          2        100
# 5         1.002405          3        100          2        100
# ...            ...        ...        ...        ...        ...
# 917548    0.998946         90         90         48         28
# 917549    0.998946         91         90        200         28
# 917550    0.998946         91         90        100         28
# 917551    0.998946         92         90        100         28
# 917552    0.998946         92         90         26         28
#
#         bid/ask spread  Total bid/ask1 Size       wap  log_return
# 1             0.000878                  103  1.001448    0.000014
# 2             0.000878                  103  1.001448    0.000000
# 3             0.000878                  129  1.001443   -0.000005
# 4             0.000878                  129  1.001443    0.000000
# 5             0.000878                  103  1.001448    0.000005
# ...                ...                  ...       ...         ...
# 917548        0.000480                  180  0.998515    0.000434
# 917549        0.000480                  181  0.998516    0.000001
# 917550        0.000480                  181  0.998516    0.000000
# 917551        0.000480                  182  0.998517    0.000001
# 917552        0.000480                  182  0.998517    0.000000
#
# [913723 rows x 14 columns]

# %%
fig ,ax = plt.subplots(figsize=(12,6))
ax.set_title('WAP of stock_id_0, time_id_5')
ax.plot(example_book_df[example_book_df['time_id']==5].seconds_in_bucket,example_book_df[example_book_df['time_id']==5].wap,color="blue",label='wap')
ax.plot(example_book_df[example_book_df['time_id']==5].seconds_in_bucket,example_book_df[example_book_df['time_id']==5].ask_price1,color="green",label='ask_price1')
ax.plot(example_book_df[example_book_df['time_id']==5].seconds_in_bucket,example_book_df[example_book_df['time_id']==5].bid_price1,color="orange",label='bid_price1')
ax.set_xlabel('seconds_in_bucket')
ax.set_ylabel('wap')
ax.legend()

fig ,ax = plt.subplots(figsize=(12,6))
ax.set_title('Log return of stock_id_0, time_id_5')
ax.plot(example_book_df[example_book_df['time_id']==5].seconds_in_bucket,example_book_df[example_book_df['time_id']==5].log_return,color="blue")
ax.plot(example_book_df[example_book_df['time_id']==5].seconds_in_bucket,example_book_df[example_book_df['time_id']==5].log_return.cumsum(),color="red",label='cumulative return')
ax.set_xlabel('seconds_in_bucket')
ax.set_ylabel('log_return')
plt.show()

# %% [markdown]
# # Construct Kaggle Realized Volatility per Time_ID for stock_id == 0

# %%
def realized_volatility(series_log_return):
    return np.sqrt(np.sum(series_log_return**2))

df_realized_vol_per_stock =  example_book_df.groupby(['time_id'])['log_return'].agg(realized_volatility).reset_index(name='realized_volatility')
df_realized_vol_per_stock
# Out:
#       time_id  realized_volatility
# 0           5             0.004499
# 1          11             0.001204
# 2          16             0.002369
# 3          31             0.002574
# 4          62             0.001894
# ...       ...                  ...
# 3825    32751             0.002579
# 3826    32753             0.002206
# 3827    32758             0.002913
# 3828    32763             0.003046
# 3829    32767             0.001901
#
# [3830 rows x 2 columns]

# %%
fig ,ax = plt.subplots(figsize=(20,6))
ax.set_title('Realized Volatility of stock_id_0')
ax.plot(df_realized_vol_per_stock.time_id,df_realized_vol_per_stock.realized_volatility,color="blue")
ax.set_xlabel('time_id')
ax.set_ylabel('realized volatility')
plt.show()

# %% [markdown]
# # Naive Prediction: Using Last Timestamp realized volatility as target
#
# Now we know hoe to build our predict target, let's using realized volatility of $t_{i-1}$ to predict $t_{i}$ as predeiction benchmark.
#
# A commonly known fact about volatility is that it tends to be autocorrelated.
#
# We can use this property to implement a naive model that just "predicts" realized volatility by using whatever the realized volatility was in the initial 10 minutes.

# %%
import glob
from tqdm import tqdm
from sklearn.metrics import r2_score


list_order_book_file_train = glob.glob(r'D:\github\quant_project\optiver_dataset\book_train.parquet\*')

print(list_order_book_file_train)
print(len(list_order_book_file_train))
# Out:
# ['D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=0', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=1', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=10', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=100', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=101', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=102', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=103', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=104', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=105', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=107', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=108', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=109', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=11', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=110', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=111', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=112', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=113', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=114', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=115', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=116', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=118', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=119', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=120', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=122', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=123', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=124', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=125', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=126', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=13', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=14', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=15', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=16', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=17', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=18', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=19', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=2', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=20', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=21', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=22', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=23', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=26', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=27', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=28', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=29', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=3', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=30', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=31', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=32', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=33', 'D:\\github\\quant_project\\optiver_dataset\\book_train.parquet\\stock_id=34', 'D:\\github\\quant_project\\o ...
# 112

# %%
path = r'D:\github\quant_project\optiver_dataset\book_train.parquet\stock_id=0'

def realized_volatility_per_stock_and_time(path):

    stock_id = path.split("=")[1]
    example_book_df = pd.read_parquet(path)

    # construct item for realized volatility calculation
    example_book_df.loc[:,('bid/ask spread')] = (example_book_df['ask_price1']/example_book_df['bid_price1'])-1 # Constrcut Bid/Ask Spread.
    example_book_df.loc[:,('Total bid/ask1 Size')] = example_book_df['ask_size1'] + example_book_df['bid_size1'] 
    example_book_df.loc[:,('wap')] = (example_book_df['bid_price1']*example_book_df['ask_size1'] + example_book_df['ask_price1']*example_book_df['bid_size1']) / (example_book_df['ask_size1'] + example_book_df['bid_size1'])
    example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
    example_book_df = example_book_df[~example_book_df['log_return'].isnull()] # drop the first null return value

    # construct realized volatility
    df_realized_vol_per_stock = example_book_df.groupby(['time_id'])['log_return'].agg(realized_volatility).reset_index(name='realized_volatility')
    # for every stock, we have to built a row_id inable for us to submit the prediction result
    df_realized_vol_per_stock.loc[:,('row_id')] = df_realized_vol_per_stock['time_id'].apply(lambda x: f'{stock_id}-{x}')

    return df_realized_vol_per_stock[['row_id','realized_volatility']]

realized_volatility_per_stock_and_time(path)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#        row_id  realized_volatility
# 0         0-5             0.004499
# 1        0-11             0.001204
# 2        0-16             0.002369
# 3        0-31             0.002574
# 4        0-62             0.001894
# ...       ...                  ...
# 3825  0-32751             0.002579
# 3826  0-32753             0.002206
# 3827  0-32758             0.002913
# 3828  0-32763             0.003046
# 3829  0-32767             0.001901
#
# [3830 rows x 2 columns]

# %%
def past_realized_volatility_per_stock(list_file):
    df_past_realized = pd.DataFrame()
    for file in tqdm(list_file):
        df_past_realized = pd.concat([df_past_realized,realized_volatility_per_stock_and_time(file)],axis=0)
    return df_past_realized


df_past_realized_train = past_realized_volatility_per_stock(list_file=list_order_book_file_train)
df_past_realized_train.sort_values(by='row_id')
# Out:
#   0%|          | 0/112 [00:00<?, ?it/s]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   1%|          | 1/112 [00:01<02:19,  1.26s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   2%|▏         | 2/112 [00:02<02:31,  1.38s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   3%|▎         | 3/112 [00:04<02:46,  1.53s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   4%|▎         | 4/112 [00:05<02:38,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   4%|▍         | 5/112 [00:07<02:39,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   5%|▌         | 6/112 [00:08<02:34,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   6%|▋         | 7/112 [00:10<02:29,  1.42s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   7%|▋         | 8/112 [00:11<02:25,  1.40s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   8%|▊         | 9/112 [00:12<02:28,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#   9%|▉         | 10/112 [00:14<02:26,  1.43s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  10%|▉         | 11/112 [00:15<02:29,  1.48s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  11%|█         | 12/112 [00:17<02:27,  1.48s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  12%|█▏        | 13/112 [00:18<02:24,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  12%|█▎        | 14/112 [00:20<02:21,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  13%|█▎        | 15/112 [00:21<02:23,  1.48s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  14%|█▍        | 16/112 [00:23<02:17,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  15%|█▌        | 17/112 [00:24<02:19,  1.47s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  16%|█▌        | 18/112 [00:26<02:16,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  17%|█▋        | 19/112 [00:27<02:11,  1.42s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  18%|█▊        | 20/112 [00:28<02:10,  1.41s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  19%|█▉        | 21/112 [00:30<02:11,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  20%|█▉        | 22/112 [00:32<02:14,  1.50s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  21%|██        | 23/112 [00:33<02:18,  1.55s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  21%|██▏       | 24/112 [00:35<02:17,  1.56s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  22%|██▏       | 25/112 [00:36<02:19,  1.61s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  23%|██▎       | 26/112 [00:38<02:23,  1.67s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  24%|██▍       | 27/112 [00:40<02:21,  1.67s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  25%|██▌       | 28/112 [00:41<02:14,  1.60s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  26%|██▌       | 29/112 [00:43<02:16,  1.64s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  27%|██▋       | 30/112 [00:45<02:15,  1.65s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  28%|██▊       | 31/112 [00:46<02:11,  1.63s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  29%|██▊       | 32/112 [00:48<02:06,  1.58s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  29%|██▉       | 33/112 [00:49<02:03,  1.56s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  30%|███       | 34/112 [00:51<01:56,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  31%|███▏      | 35/112 [00:52<01:54,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  32%|███▏      | 36/112 [00:54<01:58,  1.56s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  33%|███▎      | 37/112 [00:55<01:56,  1.55s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  34%|███▍      | 38/112 [00:57<01:59,  1.62s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  35%|███▍      | 39/112 [00:59<02:04,  1.70s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  36%|███▌      | 40/112 [01:01<01:57,  1.63s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  37%|███▋      | 41/112 [01:02<01:52,  1.59s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  38%|███▊      | 42/112 [01:03<01:44,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  38%|███▊      | 43/112 [01:05<01:42,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  39%|███▉      | 44/112 [01:06<01:44,  1.54s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  40%|████      | 45/112 [01:08<01:40,  1.50s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  41%|████      | 46/112 [01:09<01:34,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  42%|████▏     | 47/112 [01:11<01:36,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  43%|████▎     | 48/112 [01:12<01:37,  1.52s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  44%|████▍     | 49/112 [01:14<01:31,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  45%|████▍     | 50/112 [01:15<01:31,  1.47s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  46%|████▌     | 51/112 [01:17<01:33,  1.53s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  46%|████▋     | 52/112 [01:18<01:31,  1.53s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  47%|████▋     | 53/112 [01:20<01:27,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  48%|████▊     | 54/112 [01:21<01:22,  1.43s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  49%|████▉     | 55/112 [01:23<01:22,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  50%|█████     | 56/112 [01:24<01:19,  1.43s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  51%|█████     | 57/112 [01:25<01:17,  1.40s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  52%|█████▏    | 58/112 [01:27<01:18,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  53%|█████▎    | 59/112 [01:28<01:16,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  54%|█████▎    | 60/112 [01:30<01:19,  1.52s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  54%|█████▍    | 61/112 [01:32<01:18,  1.55s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  55%|█████▌    | 62/112 [01:33<01:16,  1.53s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  56%|█████▋    | 63/112 [01:35<01:15,  1.54s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  57%|█████▋    | 64/112 [01:36<01:12,  1.51s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  58%|█████▊    | 65/112 [01:38<01:09,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  59%|█████▉    | 66/112 [01:39<01:09,  1.51s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  60%|█████▉    | 67/112 [01:41<01:08,  1.51s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  61%|██████    | 68/112 [01:42<01:06,  1.51s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  62%|██████▏   | 69/112 [01:44<01:03,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  62%|██████▎   | 70/112 [01:45<01:00,  1.43s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  63%|██████▎   | 71/112 [01:46<01:01,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  64%|██████▍   | 72/112 [01:48<00:58,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  65%|██████▌   | 73/112 [01:49<00:56,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  66%|██████▌   | 74/112 [01:51<00:54,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  67%|██████▋   | 75/112 [01:52<00:51,  1.40s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  68%|██████▊   | 76/112 [01:54<00:52,  1.47s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  69%|██████▉   | 77/112 [01:55<00:51,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  70%|██████▉   | 78/112 [01:57<00:50,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# ...
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  78%|███████▊  | 87/112 [02:10<00:35,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  79%|███████▊  | 88/112 [02:11<00:34,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  79%|███████▉  | 89/112 [02:13<00:32,  1.43s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  80%|████████  | 90/112 [02:15<00:35,  1.60s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  81%|████████▏ | 91/112 [02:16<00:34,  1.62s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  82%|████████▏ | 92/112 [02:18<00:31,  1.58s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  83%|████████▎ | 93/112 [02:19<00:29,  1.55s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  84%|████████▍ | 94/112 [02:21<00:26,  1.50s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  85%|████████▍ | 95/112 [02:22<00:25,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  86%|████████▌ | 96/112 [02:23<00:23,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  87%|████████▋ | 97/112 [02:25<00:21,  1.43s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  88%|████████▊ | 98/112 [02:26<00:20,  1.45s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  88%|████████▊ | 99/112 [02:28<00:19,  1.47s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  89%|████████▉ | 100/112 [02:29<00:17,  1.49s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  90%|█████████ | 101/112 [02:31<00:16,  1.46s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  91%|█████████ | 102/112 [02:32<00:14,  1.41s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  92%|█████████▏| 103/112 [02:34<00:12,  1.42s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  93%|█████████▎| 104/112 [02:35<00:11,  1.40s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  94%|█████████▍| 105/112 [02:36<00:09,  1.38s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  95%|█████████▍| 106/112 [02:38<00:08,  1.42s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  96%|█████████▌| 107/112 [02:39<00:07,  1.42s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  96%|█████████▋| 108/112 [02:41<00:05,  1.50s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  97%|█████████▋| 109/112 [02:42<00:04,  1.53s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  98%|█████████▊| 110/112 [02:44<00:02,  1.47s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
#  99%|█████████▉| 111/112 [02:45<00:01,  1.44s/it]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
# 100%|██████████| 112/112 [02:47<00:00,  1.49s/it]
#        row_id  realized_volatility
# 103    0-1000             0.001731
# 1185  0-10000             0.002863
# 1186  0-10005             0.008673
# 1187  0-10017             0.014300
# 1188  0-10030             0.002503
# ...       ...                  ...
# 1180  99-9972             0.001629
# 1181  99-9973             0.009243
# 1182  99-9976             0.005455
# 1183  99-9988             0.001239
# 1184  99-9993             0.002591
#
# [428932 rows x 2 columns]

# %%
train = pd.read_csv(r'D:\github\quant_project\optiver_dataset\train.csv')
train['row_id'] = train['stock_id'].astype(str) + '-' + train['time_id'].astype(str)
train = train[['row_id','target']]
train
# Out:
#            row_id    target
# 0             0-5  0.004136
# 1            0-11  0.001445
# 2            0-16  0.002168
# 3            0-31  0.002195
# 4            0-62  0.001747
# ...           ...       ...
# 428927  126-32751  0.003461
# 428928  126-32753  0.003113
# 428929  126-32758  0.004070
# 428930  126-32763  0.003357
# 428931  126-32767  0.002090
#
# [428932 rows x 2 columns]

# %% [markdown]
# - Join the df_train and realized_volatility

# %%
df_joined = train.merge(df_past_realized_train, on = ['row_id'], how = 'left')
df_joined
# Out:
#            row_id    target  realized_volatility
# 0             0-5  0.004136             0.004499
# 1            0-11  0.001445             0.001204
# 2            0-16  0.002168             0.002369
# 3            0-31  0.002195             0.002574
# 4            0-62  0.001747             0.001894
# ...           ...       ...                  ...
# 428927  126-32751  0.003461             0.003691
# 428928  126-32753  0.003113             0.004104
# 428929  126-32758  0.004070             0.003118
# 428930  126-32763  0.003357             0.003661
# 428931  126-32767  0.002090             0.002091
#
# [428932 rows x 3 columns]

# %%
def rmspe(y_true, y_pred):
    return  (np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))))

R2 = round(r2_score(y_true = df_joined['target'], y_pred = df_joined['realized_volatility']),3)
RMSPE = round(rmspe(y_true = df_joined['target'], y_pred = df_joined['realized_volatility']),3)

print(f'Performance of the naive prediction:\nR2 score: {R2}, \nRMSPE: {RMSPE}.')
# Out:
# Performance of the naive prediction:
# R2 score: 0.628,
# RMSPE: 0.341.

# %% [markdown]
# # Kaggle Submision

# %%
list_order_book_file_test = glob.glob(r'D:\github\quant_project\optiver_dataset\book_test.parquet\*')
list_order_book_file_test
# Out:
# ['D:\\github\\quant_project\\optiver_dataset\\book_test.parquet\\stock_id=0']

# %%
df_naive_pred_test = past_realized_volatility_per_stock(list_file=list_order_book_file_test)
df_naive_pred_test
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]C:\Users\HP\AppData\Local\Temp\ipykernel_11148\1899370694.py:12: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   example_book_df.loc[:,('log_return')] = example_book_df.groupby('time_id')['wap'].apply(log_return)
# 100%|██████████| 1/1 [00:00<00:00, 53.41it/s]
#   row_id  realized_volatility
# 0    0-4             0.000294

# %%
df_naive_pred_test.to_csv('submission.csv',index = False)
